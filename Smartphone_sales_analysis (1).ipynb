# %% [markdown]
# Smartphone Sales Analysis

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/shash/Downloads/Smartphone_sales_analysis.zip")

# %%
data
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
data
# Out:
#        Brands          Models         Colors Memory                Storage  \
# 0     SAMSUNG    GALAXY M31S    Mirage Black   8 GB                 128 GB
# 1       Nokia             3.2          Steel   2 GB                  16 GB
# 2      realme             C2   Diamond Black   2 GB                    NaN
# 3     Infinix          Note 5       Ice Blue   4 GB                  64 GB
# 4       Apple      iPhone 11           Black    4GB                  64 GB
# ...       ...             ...            ...    ...                    ...
# 3109     POCO       M4 Pro 5G      Cool Blue   6 GB                 128 GB
# 3110    Nokia             225          Black    NaN  Expandable Upto 32 GB
# 3111    Apple      iPhone SE           White   2 GB                 128 GB
# 3112    Apple  iPhone 13 Pro            Gold   6 GB                 128 GB
# 3113   GIONEE             F9            Blue   3 GB                  32 GB
#
# ...

# %%
print(data.isnull().sum())
# Out:
# Brands                   0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount percentage      0
# dtype: int64

# %%
data.dropna()
# Out:
#        Brands            Models        Colors  Memory Storage Camera  Rating  \
# 0     SAMSUNG      GALAXY M31S   Mirage Black    8 GB  128 GB    Yes     4.3
# 1       Nokia               3.2         Steel    2 GB   16 GB    Yes     3.8
# 3     Infinix            Note 5      Ice Blue    4 GB   64 GB    Yes     4.2
# 4       Apple        iPhone 11          Black     4GB   64 GB    Yes     4.6
# 5      GIONEE              L800         Black    8 MB   16 MB    Yes     4.0
# ...       ...               ...           ...     ...     ...    ...     ...
# 3107  SAMSUNG  Galaxy S Duos 2          Black  512 MB    4 GB    Yes     4.0
# 3108  SAMSUNG         Metro 313         Black    4 MB    2 MB    Yes     4.2
# 3109     POCO         M4 Pro 5G     Cool Blue    6 GB  128 GB    Yes     4.4
# 3111    Apple        iPhone SE          White    2 GB  128 GB    Yes     4.5
# 3113   GIONEE               F9           Blue    3 GB   32 GB    Yes     4.2
#
# ...

# %%
data.dropna(inplace=True)

# %%
print(data.isnull().sum())
# Out:
# Brands                 0
# Models                 0
# Colors                 0
# Memory                 0
# Storage                0
# Camera                 0
# Rating                 0
# Selling Price          0
# Original Price         0
# Mobile                 0
# Discount               0
# discount percentage    0
# dtype: int64

# %%
print(data.describe())
# Out:
#             Rating  Selling Price  Original Price      Discount  \
# count  2897.000000    2897.000000     2897.000000   2897.000000
# mean      4.241319   24692.492233    26656.677943   1964.185709
# std       0.272841   26373.592602    28251.233298   5505.394873
# min       2.300000    1000.000000     1000.000000  -8000.000000
# 25%       4.100000    9990.000000    10389.000000      0.000000
# 50%       4.300000   14999.000000    16300.000000      0.000000
# 75%       4.400000   27499.000000    29999.000000   2000.000000
# max       5.000000  179900.000000   189999.000000  75000.000000
#
#        discount percentage
# count          2897.000000
# mean              6.222417
# std              11.353050
# min            -160.320641
# 25%               0.000000
# 50%               0.000000
# 75%               9.836388
# max              70.610305

# %% [markdown]
# **Smartphone sales analysis in India**

# %%
highest_rated = data.sort_values(by=["Rating"], ascending=False)
highest_rated = highest_rated.head(10)
print(highest_rated[['Brands', 'Discount']])
# Out:
#        Brands  Discount
# 2242  SAMSUNG         0
# 2879     vivo         0
# 2634    Apple         0
# 247      vivo         0
# 1655     vivo         0
# 2483    Apple         0
# 1446     vivo         0
# 675      vivo         0
# 1847   realme      3500
# 2179   realme      3500

# %% [markdown]
# **Let's a look at the number of ratings of the highest rated phone**

# %%
plt.bar(highest_rated['Brands'], highest_rated['Rating'])
plt.xlabel("Brands")
plt.ylabel("Rating")
plt.title("Ratings of highest_rated phones")
plt.show()

# %% [markdown]
# **Discount of highest_rated phones**

# %%
plt.bar(highest_rated['Brands'], highest_rated['Discount'])
plt.xlabel("Brands")
plt.ylabel("Discount")
plt.title("Discount of highest_rated phones")
plt.show()

# %% [markdown]
# **Relationship between Selling price and Rating**

# %%
data_frame = pd.DataFrame(data)
x = data_frame['Rating']
y = data_frame['Selling Price']
plt.scatter(x, y, c="r")
plt.xlabel("Rating")
plt.ylabel("Selling Price")
plt.title("Relationship between Selling Price and rating")
plt.show()
